# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#Quick Test
x = torch.randn(5,5)
print(f"\nTest Tensor:\n{x}")

plt.figure(figsize = (6,4))
plt.plot([1,2,3,4],[1,4,2,3])
plt.title("Test Plot")
plt.show()

print("Everything works!")
# Out:
# Test Tensor:
# tensor([[ 0.5904, -1.0230, -0.6649, -0.4686,  0.9070],
#         [ 0.5187,  0.1469, -0.1570, -0.5633,  0.1592],
#         [ 0.5423,  1.3585, -0.6360, -0.2752, -1.6683],
#         [ 1.7019, -0.5176,  0.2572,  1.1235, -0.5334],
#         [ 1.0598,  0.1173,  0.2447, -0.3067, -0.5303]])
# Everything works!

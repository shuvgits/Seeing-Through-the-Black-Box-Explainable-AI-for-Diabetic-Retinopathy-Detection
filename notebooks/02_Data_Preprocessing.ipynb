# %%
import sys
sys.path.append('../src') 

from preprocessing import *
from pathlib import Path
import matplotlib.pyplot as plt
# %matplotlib inline

print("Preprocessing module loaded!")
# Out:
# Preprocessing module loaded!

# %%
# Find a sample image
data_path = Path('../data/raw/idrid')
sample_images = list(data_path.rglob('*.jpg'))

print(f"Found {len(sample_images)} images")
print(f"Testing on: {sample_images[0].name}")
# Out:
# Found 1113 images
# Testing on: IDRiD_27.jpg

# %%
# Test the preprocessing
visualize_preprocessing(sample_images[0], target_size=512)
# Out:
# Original shape: (2848, 4288, 3)
# Original value range: [0, 255]
# Preprocessed shape: (512, 512, 3)
# Preprocessed value range: [0.000, 1.000]

# %%
# Test on multiple images
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.flatten()

for idx in range(6):
    img_path = sample_images[idx]
    preprocessed = preprocess_image(img_path, target_size=512)
    
    axes[idx].imshow(preprocessed)
    axes[idx].set_title(f"{img_path.name}\n512×512")
    axes[idx].axis('off')

plt.tight_layout()
plt.show()

print("Preprocessing works on multiple images!")
# Out:
# Preprocessing works on multiple images!
